# %%
#This part of code, the goal is to go from mapping and county level weather data to to subgroup data
# Define paths
data_and_output_dir = '/Users/ansonkong/Downloads/Data for nyu work/'
full_future_data_path = '/Users/ansonkong/Downloads/rcp85hotter/'
full_historical_data_path = '/Users/ansonkong/Downloads/historic/'

#this just smooth out operation
cutoff_year=2020 #The year prediction dataset start
start_year=2000 #The year historical 
end_year=2100

#Debug mode(only output once)
debug=False

# %%
#create population level data
#import require file
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import os
from datetime import datetime
from glob import glob


#Path, this will update itself
mapping_path = data_and_output_dir + 'output/merged_rb_control_area_mapping.csv'
future_population_data_path = data_and_output_dir + 'input/Electric_Retail_Service_Territories/ssp3_county_population.csv'
historical_population_data_path = data_and_output_dir + 'input/county_populations_2000_to_2020.csv'
output_path = data_and_output_dir + 'output/'

# Load mapping and population data
mapping_df = pd.read_csv(mapping_path)
future_population_df = pd.read_csv(future_population_data_path)
historical_population_df = pd.read_csv(historical_population_data_path)

#crate looping for interp
years = np.arange(cutoff_year, end_year + 1, 10)
interp_years = np.arange(cutoff_year, end_year + 1)

# Ensure FIPS codes are five zero-padded strings
historical_population_df['FIPS'] = historical_population_df['county_FIPS'].astype(str).str.zfill(5)
future_population_df['FIPS'] = future_population_df['FIPS'].astype(str).str.zfill(5)
mapping_df['GEOID'] = mapping_df['GEOID'].astype(str).str.zfill(5)

# Rename 'pop_{year}' columns to just '{year}'
for year in range(start_year, cutoff_year+1):
    if f'pop_{year}' in historical_population_df.columns:
        historical_population_df.rename(columns={f'pop_{year}': str(year)}, inplace=True)



# Assuming 'FIPS' is the column to join on and 'Year' is the column indicating the year in future_population_df
for index, row in future_population_df.iterrows():
    pop_values = [row[str(year)] for year in years if str(year) in row]
    interpolator = interp1d(years, pop_values, kind='linear', fill_value="extrapolate")
    interpolated_values = interpolator(interp_years)
    for year in interp_years:
        future_population_df.at[index, str(year)] = interpolated_values[year - cutoff_year]


# Select relevant columns for historical data
historical_population_df = historical_population_df[['FIPS'] + [str(year) for year in range(start_year, cutoff_year)]]

# Select relevant columns for future data
future_population_df = future_population_df[['FIPS'] + [str(year) for year in interp_years]]

# Concatenate historical and future dataframes
combined_population_df = pd.merge(historical_population_df, future_population_df, on='FIPS', how='outer')
# Merge combined population data with mapping data
# Assuming 'GEOID' in mapping_df corresponds to 'FIPS' in population data
combined_df = pd.merge(mapping_df, combined_population_df, left_on='GEOID', right_on='FIPS', how='inner')
combined_df['FIPS']=combined_df['GEOID']

# Identify FIPS codes in mapping_df that did not successfully join
missing_in_combined = set(mapping_df['GEOID']) - set(combined_df['GEOID'])
print(missing_in_combined)
for column in combined_df.columns:
    print(column)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (
# set()
# STATEFP
# COUNTYFP
# COUNTYNS
# AFFGEOID
# GEOID
# NAME
# LSAD
# ALAND
# AWATER
# geometry
# FIPS_x
# rb
# is_mainland
# CNTRL_AREA
# FIPS_y
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# 2051
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065
# 2066
# 2067
# 2068
# 2069
# 2070
# 2071
# 2072
# 2073
# 2074
# 2075
# 2076
# 2077
# 2078
# 2079
# 2080
# 2081
# 2082
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# 2091
# 2092
# 2093
# 2094
# 2095
# 2096
# 2097
# 2098
# 2099
# 2100
# FIPS

# %%
# problem with 2018 and 2019 rerun

# %%
# main

historical_weather_path = os.path.join(output_path, 'historical_weather')
future_weather_path = os.path.join(output_path, 'future_weather')
os.makedirs(historical_weather_path, exist_ok=True)
os.makedirs(future_weather_path, exist_ok=True)
# Function to load checkpoint
def load_checkpoint(year):
    checkpoint_file = os.path.join(output_path, 'checkpoint.txt')
    if os.path.exists(checkpoint_file):
        with open(checkpoint_file, 'r') as file:
            completed_years = file.read().splitlines()
        return str(year) in completed_years
    return False

# Function to save checkpoint
def save_checkpoint(year):
    checkpoint_file = os.path.join(output_path, 'checkpoint.txt')
    with open(checkpoint_file, 'a') as file:
        file.write(f"{year}\n")
yearloopbreaker=False
fileloopbreaker=False
rbloopbreaker=False
for year in range(start_year, end_year + 1):

    if yearloopbreaker:break
    if load_checkpoint(year):
        print(f"Year {year} already processed. Skipping.")
        continue


    print(f'Process start for year: {year}')
    if year < cutoff_year:
        folder_to_read = os.path.join(full_historical_data_path, str(year))
        folder_to_store = historical_weather_path
    else:
        folder_to_read = os.path.join(full_future_data_path, str(year))
        folder_to_store = future_weather_path
    
    # Initialize a dictionary to hold DataFrames for each rb
    rb_dfs = {}
    # Sort files before processing
    files = sorted(glob(os.path.join(folder_to_read, '*.csv')))
    total_files = len(files)
    processed_files = 0

    # Iterate through each file in the year's folder
    for file_path in files:
        processed_files += 1
        #print(f"Processing file {processed_files}/{total_files} ({(processed_files/total_files)*100:.2f}%)")

        if fileloopbreaker:break
        
        meteorology_df = pd.read_csv(file_path)
        if meteorology_df.empty:
            print(f"Skipped empty file: {file_path}")
            continue
        #print(meteorology_df.columns)
        meteorology_df['FIPS'] = meteorology_df['FIPS'].astype(str).str.zfill(5)
        meteorology_df['WSPD'] = np.sqrt(meteorology_df['U10']**2 + meteorology_df['V10']**2)
        
        # Extract date and time from file name
        _, month, day, hour = map(int, os.path.basename(file_path).split('_')[:4])
        utc_time = datetime(year, month, day, hour).strftime('%Y-%m-%d %H:%M:%S')
        meteorology_df['Time_UTC'] = utc_time
        
        # Merge with background data
        merged_df = pd.merge(combined_df, meteorology_df, on='FIPS', how='inner')
        
        # Calculate weighted averages and accumulate in rb_dfs
        merged_df['Population'] = merged_df[str(year)]
        for rb, group in merged_df.groupby('rb'):
            if rbloopbreaker:break
            
            if rb not in rb_dfs:
                rb_dfs[rb] = pd.DataFrame()
            weighted = group.copy()
            
            for col in ['T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']:
                weighted[col] = weighted[col] * weighted['Population']
            weighted_sum = weighted.groupby('rb').sum()
            for col in ['T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']:
                weighted_sum[col] = weighted_sum[col] / weighted_sum['Population']
            weighted_sum['Time_UTC'] = utc_time
            weighted_sum=weighted_sum[['Time_UTC','T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']]
            rb_dfs[rb] = pd.concat([rb_dfs[rb], weighted_sum.reset_index()], ignore_index=True)
        if debug:
            fileloopbreaker=True
            yearloopbreaker=True
    save_checkpoint(year)

    
    # Save each RB's accumulated data to its file
    for rb, df in rb_dfs.items():
        output_file = os.path.join(folder_to_store, f"{rb}_WRF_Hourly_Mean_Meteorology_{year}.csv")
        df.sort_values(by='Time_UTC', inplace=True)
        df[['Time_UTC','T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']].to_csv(output_file, index=False)
        print(f"Processed and saved: {output_file} for RB: {rb}")
# Out:
# Year 2000 already processed. Skipping.
# Year 2001 already processed. Skipping.
# Year 2002 already processed. Skipping.
# Year 2003 already processed. Skipping.
# Year 2004 already processed. Skipping.
# Year 2005 already processed. Skipping.
# Year 2006 already processed. Skipping.
# Year 2007 already processed. Skipping.
# Year 2008 already processed. Skipping.
# Year 2009 already processed. Skipping.
# Year 2010 already processed. Skipping.
# Year 2011 already processed. Skipping.
# Year 2012 already processed. Skipping.
# Year 2013 already processed. Skipping.
# Year 2014 already processed. Skipping.
# Year 2015 already processed. Skipping.
# Year 2016 already processed. Skipping.
# Year 2017 already processed. Skipping.
# Year 2018 already processed. Skipping.
# Year 2019 already processed. Skipping.
# Year 2020 already processed. Skipping.
# Year 2021 already processed. Skipping.
# Year 2022 already processed. Skipping.
# Year 2023 already processed. Skipping.
# Year 2024 already processed. Skipping.
# Year 2025 already processed. Skipping.
# Year 2026 already processed. Skipping.
# Year 2027 already processed. Skipping.
# Year 2028 already processed. Skipping.
# Year 2029 already processed. Skipping.
# Year 2030 already processed. Skipping.
# Year 2031 already processed. Skipping.
# Year 2032 already processed. Skipping.
# Year 2033 already processed. Skipping.
# Year 2034 already processed. Skipping.
# Year 2035 already processed. Skipping.
# Year 2036 already processed. Skipping.
# Year 2037 already processed. Skipping.
# Year 2038 already processed. Skipping.
# Year 2039 already processed. Skipping.
# Year 2040 already processed. Skipping.
# Year 2041 already processed. Skipping.
# Year 2042 already processed. Skipping.
# Year 2043 already processed. Skipping.
# Year 2044 already processed. Skipping.
# Year 2045 already processed. Skipping.
# Year 2046 already processed. Skipping.
# Year 2047 already processed. Skipping.
# Year 2048 already processed. Skipping.
# Year 2049 already processed. Skipping.
# Year 2050 already processed. Skipping.
# Year 2051 already processed. Skipping.
# Year 2052 already processed. Skipping.
# Year 2053 already processed. Skipping.
# Year 2054 already processed. Skipping.
# Year 2055 already processed. Skipping.
# Year 2056 already processed. Skipping.
# Year 2057 already processed. Skipping.
# Year 2058 already processed. Skipping.
# Year 2059 already processed. Skipping.
# Year 2060 already processed. Skipping.
# Year 2061 already processed. Skipping.
# Year 2062 already processed. Skipping.
# Year 2063 already processed. Skipping.
# Year 2064 already processed. Skipping.
# Year 2065 already processed. Skipping.
# Year 2066 already processed. Skipping.
# Year 2067 already processed. Skipping.
# Year 2068 already processed. Skipping.
# Year 2069 already processed. Skipping.
# Year 2070 already processed. Skipping.
# Year 2071 already processed. Skipping.
# Year 2072 already processed. Skipping.
# Year 2073 already processed. Skipping.
# Year 2074 already processed. Skipping.
# Year 2075 already processed. Skipping.
# Year 2076 already processed. Skipping.
# Year 2077 already processed. Skipping.
# Year 2078 already processed. Skipping.
# Year 2079 already processed. Skipping.
# Year 2080 already processed. Skipping.
# Year 2081 already processed. Skipping.
# Year 2082 already processed. Skipping.
# Year 2083 already processed. Skipping.
# Year 2084 already processed. Skipping.
# Year 2085 already processed. Skipping.
# Year 2086 already processed. Skipping.
# Year 2087 already processed. Skipping.
# Year 2088 already processed. Skipping.
# Year 2089 already processed. Skipping.
# Year 2090 already processed. Skipping.
# Year 2091 already processed. Skipping.
# Year 2092 already processed. Skipping.
# Year 2093 already processed. Skipping.
# Year 2094 already processed. Skipping.
# Year 2095 already processed. Skipping.
# Year 2096 already processed. Skipping.
# Year 2097 already processed. Skipping.
# Year 2098 already processed. Skipping.
# Year 2099 already processed. Skipping.
# Year 2100 already processed. Skipping.

# %%
# # rerun for 2018,2019,2020
# historical_weather_path = os.path.join(output_path, 'historical_weather')
# future_weather_path = os.path.join(output_path, 'future_weather')
# os.makedirs(historical_weather_path, exist_ok=True)
# os.makedirs(future_weather_path, exist_ok=True)
# # Function to load checkpoint
# def load_checkpoint(year):
#     checkpoint_file = os.path.join(output_path, 'checkpoint.txt')
#     if os.path.exists(checkpoint_file):
#         with open(checkpoint_file, 'r') as file:
#             completed_years = file.read().splitlines()
#         return str(year) in completed_years
#     return False

# # Function to save checkpoint
# def save_checkpoint(year):
#     checkpoint_file = os.path.join(output_path, 'checkpoint.txt')
#     with open(checkpoint_file, 'a') as file:
#         file.write(f"{year}\n")
# yearloopbreaker=False
# fileloopbreaker=False
# rbloopbreaker=False
# for year in [2018,2019,2020]:

#     if yearloopbreaker:break


#     print(f'Process start for year: {year}')
#     if year < cutoff_year:
#         folder_to_read = os.path.join(full_historical_data_path, str(year))
#         folder_to_store = historical_weather_path
#     else:
#         folder_to_read = os.path.join(full_future_data_path, str(year))
#         folder_to_store = future_weather_path
    
#     # Initialize a dictionary to hold DataFrames for each rb
#     rb_dfs = {}
#     # Sort files before processing
#     files = sorted(glob(os.path.join(folder_to_read, '*.csv')))
#     total_files = len(files)
#     processed_files = 0

#     # Iterate through each file in the year's folder
#     for file_path in files:
#         processed_files += 1
#         #print(f"Processing file {processed_files}/{total_files} ({(processed_files/total_files)*100:.2f}%)")

#         if fileloopbreaker:break
        
#         meteorology_df = pd.read_csv(file_path)
#         if meteorology_df.empty:
#             print(f"Skipped empty file: {file_path}")
#             continue
#         #print(meteorology_df.columns)
#         meteorology_df['FIPS'] = meteorology_df['FIPS'].astype(str).str.zfill(5)
#         meteorology_df['WSPD'] = np.sqrt(meteorology_df['U10']**2 + meteorology_df['V10']**2)
        
#         # Extract date and time from file name
#         _, month, day, hour = map(int, os.path.basename(file_path).split('_')[:4])
#         utc_time = datetime(year, month, day, hour).strftime('%Y-%m-%d %H:%M:%S')
#         meteorology_df['Time_UTC'] = utc_time
        
#         # Merge with background data
#         merged_df = pd.merge(combined_df, meteorology_df, on='FIPS', how='inner')
        
#         # Calculate weighted averages and accumulate in rb_dfs
#         merged_df['Population'] = merged_df[str(year)]
#         for rb, group in merged_df.groupby('rb'):
#             if rbloopbreaker:break
            
#             if rb not in rb_dfs:
#                 rb_dfs[rb] = pd.DataFrame()
#             weighted = group.copy()
            
#             for col in ['T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']:
#                 weighted[col] = weighted[col] * weighted['Population']
#             weighted_sum = weighted.groupby('rb').sum()
#             for col in ['T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']:
#                 weighted_sum[col] = weighted_sum[col] / weighted_sum['Population']
#             weighted_sum['Time_UTC'] = utc_time
#             weighted_sum=weighted_sum[['Time_UTC','T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']]
#             rb_dfs[rb] = pd.concat([rb_dfs[rb], weighted_sum.reset_index()], ignore_index=True)
#         if debug:
#             fileloopbreaker=True
#             yearloopbreaker=True

    
#     # Save each RB's accumulated data to its file
#     for rb, df in rb_dfs.items():
#         output_file = os.path.join(folder_to_store, f"{rb}_WRF_Hourly_Mean_Meteorology_{year}.csv")
#         df.sort_values(by='Time_UTC', inplace=True)
#         df[['Time_UTC','T2', 'Q2', 'SWDOWN', 'GLW', 'WSPD']].to_csv(output_file, index=False,mode='w+')
#         print(f"Processed and saved: {output_file} for RB: {rb}")
# Out:
# Process start for year: 2018
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_08_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_09_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_10_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_11_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_12_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_13_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_14_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_15_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_16_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_17_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_18_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_19_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_20_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_21_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_22_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_23_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_24_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_21_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_22_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_25_23_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_00_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_01_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_02_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_03_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_04_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_05_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_06_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_07_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_08_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_09_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_10_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_11_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_12_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_13_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_14_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_15_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_16_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_17_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_18_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_19_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_20_UTC_County_Mean_Meteorology.csv
# Skipped empty file: /Users/ansonkong/Downloads/historic/2018/2018_08_26_21_UTC_County_Mean_Meteorology.csv
# ...
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p118_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p118
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p119_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p119
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p12_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p12
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p120_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p120
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p121_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p121
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p122_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p122
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p123_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p123
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p124_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p124
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p125_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p125
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p126_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p126
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p127_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p127
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p128_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p128
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p129_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p129
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p13_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p13
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p130_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p130
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p131_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p131
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p132_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p132
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p133_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p133
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p134_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p134
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p14_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p14
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p15_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p15
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p16_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p16
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p17_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p17
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p18_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p18
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p19_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p19
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p2_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p2
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p20_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p20
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p21_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p21
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p22_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p22
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p23_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p23
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p24_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p24
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p25_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p25
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p26_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p26
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p27_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p27
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p28_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p28
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p29_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p29
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p3_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p3
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p30_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p30
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p31_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p31
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p32_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p32
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p33_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p33
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p34_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p34
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p35_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p35
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p36_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p36
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p37_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p37
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p38_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p38
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p39_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p39
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p4_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p4
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p40_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p40
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p41_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p41
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p42_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p42
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p43_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p43
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p44_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p44
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p45_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p45
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p46_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p46
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p47_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p47
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p48_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p48
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p49_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p49
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p5_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p5
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p50_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p50
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p51_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p51
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p52_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p52
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p53_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p53
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p54_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p54
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p55_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p55
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p56_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p56
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p57_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p57
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p58_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p58
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p59_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p59
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p6_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p6
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p60_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p60
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p61_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p61
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p62_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p62
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p63_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p63
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p64_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p64
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p65_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p65
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p66_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p66
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p67_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p67
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p68_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p68
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p69_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p69
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p7_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p7
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p70_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p70
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p71_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p71
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p72_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p72
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p73_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p73
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p74_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p74
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p75_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p75
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p76_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p76
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p77_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p77
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p78_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p78
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p79_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p79
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p8_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p8
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p80_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p80
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p81_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p81
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p82_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p82
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p83_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p83
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p84_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p84
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p85_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p85
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p86_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p86
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p87_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p87
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p88_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p88
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p89_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p89
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p9_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p9
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p90_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p90
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p91_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p91
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p92_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p92
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p93_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p93
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p94_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p94
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p95_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p95
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p96_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p96
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p97_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p97
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p98_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p98
# Processed and saved: /Users/ansonkong/Downloads/Data for nyu work/output/future_weather/p99_WRF_Hourly_Mean_Meteorology_2020.csv for RB: p99

# %%
meteorology_df = pd.read_csv(file_path)

# %%
meteorology_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []
